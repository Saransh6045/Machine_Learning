# %% [markdown]
# <a href="https://colab.research.google.com/github/Saransh6045/Machine_Learning/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #print

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Machine Learning" + " Basics")
# Out:
# Machine Learning Basics

# %%
print(9)
# Out:
# 9

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #Basic Data Types
# * int
# * str
# * float

# %%
type(8)
# Out:
# int

# %% [markdown]
# #Constant & Variables

# %% [markdown]
# #input

# %% [markdown]
# #Basic Data Types
# 1. Integer
# 2. Float
# 3. Complex
# 4. Boolean
# 5. String

# %% [markdown]
# Types of objects in Python
# 1. Immutable objects
# 2. Mutable objects
#
# Mutable objects:
#
#
# *   int
# *   float
# *   str
# *   bool
# *   tuple
#
# Immutable objects:
#
#
# *  List
# *   Set
# *  Dictionary

# %% [markdown]
# #Operators in Python
# 1. Arithmetic Operators
# 2. Assignment Operators
# 3. Comparison Operators
# 4. Logical Operators
# 5. Identity Operators
# 6. Membership Operators

# %% [markdown]
# #if else statements, if elif, nested if

# %% [markdown]
# #Loops in Python

# %% [markdown]
# #Functions in Python

# %%
# !echo "# Machine_Learning" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/Saransh6045/Machine_Learning.git
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@887bd72eb06c.(none)')
# error: src refspec main does not match any
# ...

# %%
# !git config --global user.email "proengineer108@gmail.com"
# !git config --global user.name "Saransh Varshney"

# %%
# !git init
# !echo "# Machine_Learning" >> README.md
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/Saransh6045/Machine_Learning.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/.git/
# [main 3d9d734] first commit
#  1 file changed, 1 insertion(+)
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address
